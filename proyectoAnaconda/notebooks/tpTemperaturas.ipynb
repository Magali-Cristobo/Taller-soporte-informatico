# %%
import pandas as pd
import seaborn as sb

df1 = pd.read_csv("../data/historico_temperaturas.csv",sep=",",engine="python" )
# df1 = df1.loc[0:2500]
# df1["Multa (UT)"] = df1["Multa (UT)"].apply(eliminarPesos)
grafico = sb.pairplot(df1,hue="mes",palette="Spectral",height=3)
